# %% [markdown]
# **TENSORFLOW**
# 0909i

# %%
import tensorflow as tf

import numpy as np


#step 1: Convert data toNumpy arrays
x = np.array([1,2,3,4], dtype=float)
y = np.array([2,4,6,8], dtype=float)

#step 2: Define model usig input layer (recommended)
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

#model = tf.keras.Sequential([tf.keras.input(shape=(1,)),tf.keras.layers.Dense(1)])


#step 3: compile the model
model.compile(optimizer = 'sgd', loss='mean_squared_error')

#step 4: train the model
model.fit(x,y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - loss: 28.1153
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 19.5261
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 13.5661
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 9.4305
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 6.5608
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 4.5694
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 3.1876
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 2.2286
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.5631
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.1013

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#Covert lists to numpy arrays

x = np.array([1,2,3,4], dtype= float)
y = np.array([2,4,6,8], dtype= float)

#define the model
model = Sequential([
    Dense (1, input_shape=(1,)) #this works, or you can use tf.keras.Iput
])


#compile the model
model.compile(optimizer='sgd', loss='mse')

#Train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 86.6666
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 60.1900
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 41.8181
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 29.0699
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 20.2238
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 14.0854
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.8258
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 6.8699
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.8185
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 3.3948

# %%
import torch
import torch.nn as nn
import torch.optim as optim


#define a simple linear model
model = nn.Linear(1, 1)


#Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)


#dummy data
x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

#Training loop
for epoch in range(10):
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterion(outputs, y)
  loss.backward()
  optimizer.step()
  print("Epoch {epoch +1}, Loss: {loss.item()}")
# Out:
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
# Epoch {epoch +1}, Loss: {loss.item()}
